# %%
from astroquery.jplhorizons import Horizons
from astropy.time import Time

epochs = Time('2029-04-13 00:00:00', format='iso', scale='utc')

planet = {
    'MERCURY': {'id': '1', 'm': '1.6601367952719304D-07', 'r': '20.D0', 'd': '5.43D0'},
    'VENUS':   {'id': '2', 'm': '2.4478383396645443D-06', 'r': '20.D0', 'd': '5.24D0'},
    #'EARTHMOON':   {'id': '3', 'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    'MARS':    {'id': '4', 'm': '3.2271514450538653D-07', 'r': '20.D0', 'd': '3.93D0'},
    'JUPITER': {'id': '5', 'm': '9.5479193842432660D-04', 'r': '20.D0', 'd': '1.33D0'},
    'SATURN':  {'id': '6', 'm': '2.8588598066613081D-04', 'r': '20.D0', 'd': '0.69D0'},
    'URANUS':  {'id': '7', 'm': '4.3662440433515630D-05', 'r': '20.D0', 'd': '1.27D0'},
    'NEPTUNE': {'id': '8', 'm': '5.1513890204661145D-05', 'r': '20.D0', 'd': '1.64D0'},
    'EARTH':   {'id': '399', 'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    'MOON':    {'id': '301', 'm': '3.694873455835E-08', 'r': '20.D0', 'd': '3.34D0'}
}

object = {
    #'KAMOOALEWA': {'id': '469219'},
    #'2023FW13': {'id': '2023 FW13'},
    'APOPHIS': {'id': 'Apophis'}
}

# %%
print(f"Epoch : {epochs.jd}")

for name, info in planet.items():

    obj = Horizons(id=info['id'], location='@sun', epochs=epochs.jd)
    vec = obj.vectors()

    x, y, z = vec['x'][0], vec['y'][0], vec['z'][0]
    vx, vy, vz = vec['vx'][0], vec['vy'][0], vec['vz'][0]

    def to_d_format(val):

        return f"{val: .16E}".replace('E', 'D')

    print(f" {name:<10} m={info['m']} r={info['r']} d={info['d']}")
    print(f"  {to_d_format(x)} {to_d_format(y)} {to_d_format(z)}")
    print(f"  {to_d_format(vx)} {to_d_format(vy)} {to_d_format(vz)}")
    print(" 0.D0 0.D0 0.D0")
# Out:
# Epoch : 2462239.5
#  MERCURY    m=1.6601367952719304D-07 r=20.D0 d=5.43D0
#   -9.8037758319908117D-02  2.9764092686853111D-01  3.3316716553604263D-02
#   -3.2370326320594972D-02 -7.7631033075729588D-03  2.3342247310309460D-03
#  0.D0 0.D0 0.D0
#  VENUS      m=2.4478383396645443D-06 r=20.D0 d=5.24D0
#    5.9072373713771531D-01  4.1738690574076531D-01 -2.8346205704176002D-02
#   -1.1733739648989350D-02  1.6431895656147961D-02  9.0292304837675467D-04
#  0.D0 0.D0 0.D0
#  MARS       m=3.2271514450538653D-07 r=20.D0 d=3.93D0
#   -1.5907707642127100D+00 -3.6601432228621977D-01  3.1329071237044093D-02
#    3.6586269484880358D-03 -1.2441490101549180D-02 -3.5046906544101980D-04
#  0.D0 0.D0 0.D0
#  JUPITER    m=9.5479193842432660D-04 r=20.D0 d=1.33D0
#   -5.0462302139557940D+00 -2.0581844508358178D+00  1.2145867777577020D-01
#    2.7627738234979561D-03 -6.6416832269822383D-03 -3.4210645545644798D-05
#  0.D0 0.D0 0.D0
#  SATURN     m=2.8588598066613081D-04 r=20.D0 d=0.69D0
#    6.6731399039860069D+00  6.2924904252531890D+00 -3.7519384805845379D-01
#   -4.1266443928915037D-03  4.0440303421832987D-03  9.3934097869980971D-05
#  0.D0 0.D0 0.D0
#  URANUS     m=4.3662440433515630D-05 r=20.D0 d=1.27D0
#    5.5341066648795536D+00  1.8457762069454901D+01 -3.1998913930457889D-03
#   -3.7949902071556349D-03  9.4140000076664327D-04  5.2682782832856083D-05
#  0.D0 0.D0 0.D0
#  NEPTUNE    m=5.1513890204661145D-05 r=20.D0 d=1.64D0
#    2.9540865123853290D+01  4.2825567919188483D+00 -7.6903187559434916D-01
#   -4.6951812712390302D-04  3.1203248447886560D-03 -5.3515811377127288D-05
#  0.D0 0.D0 0.D0
#  EARTH      m=3.0034895963248533D-06 r=20.D0 d=5.51D0
#   -9.2332236560247771D-01 -3.9091610584830638D-01  2.8633383705870308D-05
#    6.4294094240628574D-03 -1.5913943843875990D-02  1.0901327016015129D-06
#  0.D0 0.D0 0.D0
#  MOON       m=3.694873455835E-08 r=20.D0 d=3.34D0
#   -9.2068471506454341D-01 -3.9030215128123119D-01  2.6455729905634258D-04
#    6.3025575374749346D-03 -1.5367847978822371D-02 -3.7953628948413938D-06
#  0.D0 0.D0 0.D0

# %%
print(f"Epoch : {epochs.jd}")

for name, info in object.items():
    obj = Horizons(id=info['id'], location='@sun', epochs=epochs.jd)
    el = obj.elements()

    a, e, i, w, node, M = el['a'][0], el['e'][0], el['incl'][0], el['w'][0], el['Omega'][0], el['M'][0]

    print(f" {name:<10} ep={epochs.jd:.1f}d0")
    print(f"  {a:.16f}d0 {e:.16f}d0 {i:.16f}d0 {w:.16f}d0 {node:.16f}d0 {M:.16f}d0 0.d0 0.d0 0.d0")
# Out:
# Epoch : 2462239.5
#  APOPHIS    ep=2462239.5d0
#   0.9213887942467650d0 0.1956772965290144d0 3.4227059151236552d0 126.6230781795259048d0 203.7857099738982924d0 252.0309445149459009d0 0.d0 0.d0 0.d0
