# %%
from astroquery.jplhorizons import Horizons
from astropy.time import Time

# %%
DAYS_PER_JULIAN_YEAR = 365.25

BIG = {
    'MERCURY': {'id': '1', 'm': '1.6601367952719304D-07', 'r': '20.D0', 'd': '5.43D0'},
    'VENUS':   {'id': '2', 'm': '2.4478383396645443D-06', 'r': '20.D0', 'd': '5.24D0'},
    'EARTHMOON':   {'id': '3', 'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    'MARS':    {'id': '4', 'm': '3.2271514450538653D-07', 'r': '20.D0', 'd': '3.93D0'},
    'JUPITER': {'id': '5', 'm': '9.5479193842432660D-04', 'r': '20.D0', 'd': '1.33D0'},
    'SATURN':  {'id': '6', 'm': '2.8588598066613081D-04', 'r': '20.D0', 'd': '0.69D0'},
    'URANUS':  {'id': '7', 'm': '4.3662440433515630D-05', 'r': '20.D0', 'd': '1.27D0'},
    'NEPTUNE': {'id': '8', 'm': '5.1513890204661145D-05', 'r': '20.D0', 'd': '1.64D0'},
    #'EARTH':   {'id': '399', 'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    #'MOON':    {'id': '301', 'm': '3.694873455835E-08', 'r': '20.D0', 'd': '3.34D0'}
}

SMALL = {
    #'KAMOOALEWA': {'id': '469219'},
    #'2023FW13': {'id': '2023 FW13'},
    #'APOPHIS': {'id': 'Apophis'},
    'HEKTOR': {'id': 'Hektor'}
}

# %%
# Epoch Calculation
epochs = Time('2026-04-29 00:00:00', format='iso', scale='utc')
duration = 300 * DAYS_PER_JULIAN_YEAR
print(f"Epoch : {epochs.jd} to {epochs.jd + duration}")
# Out:
# Epoch : 2461159.5 to 2570734.5

# %%
print(f"Epoch : {epochs.jd}\n")

for name, info in BIG.items():

    obj = Horizons(id=info['id'], location='@sun', epochs=epochs.jd)
    vec = obj.vectors()

    x, y, z = vec['x'][0], vec['y'][0], vec['z'][0]
    vx, vy, vz = vec['vx'][0], vec['vy'][0], vec['vz'][0]

    def to_d_format(val):

        return f"{val: .16E}".replace('E', 'D')

    print(f" {name:<10} m={info['m']} r={info['r']} d={info['d']}")
    print(f"  {to_d_format(x)} {to_d_format(y)} {to_d_format(z)}")
    print(f"  {to_d_format(vx)} {to_d_format(vy)} {to_d_format(vz)}")
    print(" 0.D0 0.D0 0.D0")
# Out:
# Epoch : 2461159.5
#
#  MERCURY    m=1.6601367952719304D-07 r=20.D0 d=5.43D0
#    3.4864288894010448D-01 -1.6598583837648309D-01 -4.5541536268918367D-02
#    6.5957166062876760D-03  2.6677741367523711D-02  1.5752489653381449D-03
#  0.D0 0.D0 0.D0
#  VENUS      m=2.4478383396645443D-06 r=20.D0 d=5.24D0
#   -1.8937121408523030D-01  6.9322543584712271D-01  2.0450588188280831D-02
#   -1.9580213067974181D-02 -5.4427880812769691D-03  1.0549905418151440D-03
#  0.D0 0.D0 0.D0
#  EARTHMOON  m=3.0034895963248533D-06 r=20.D0 d=5.51D0
#   -7.8979771058539916D-01 -6.2456154797543051D-01  4.1898327634177768D-05
#    1.0392265109000711D-02 -1.3559203878235129D-02  7.5708647529439317D-07
#  0.D0 0.D0 0.D0
#  MARS       m=3.2271514450538653D-07 r=20.D0 d=3.93D0
#    1.3875329132335661D+00 -6.2293626045713618D-02 -3.5328796789516587D-02
#    1.1648205360597890D-03  1.5175893054413419D-02  2.8947272905005658D-04
#  0.D0 0.D0 0.D0
#  JUPITER    m=9.5479193842432660D-04 r=20.D0 d=1.33D0
#   -2.5187195924175279D+00  4.6110480125861901D+00  3.7198431486247588D-02
#   -6.7161496993065374D-03 -3.2678782117390192D-03  1.6384218335375970D-04
#  0.D0 0.D0 0.D0
#  SATURN     m=2.8588598066613081D-04 r=20.D0 d=0.69D0
#    9.4299593437152645D+00  9.1316362160838327D-01 -3.9127108231603791D-01
#   -8.4866651008480120D-04  5.5397121400658491D-03 -6.2706997299350625D-05
#  0.D0 0.D0 0.D0
#  URANUS     m=4.3662440433515630D-05 r=20.D0 d=1.27D0
#    9.4733011173339641D+00  1.7008865631613052D+01 -5.9665480100019451D-02
#   -3.4718373917184690D-03  1.7292316054108321D-03  5.1454449964178892D-05
#  0.D0 0.D0 0.D0
#  NEPTUNE    m=5.1513890204661145D-05 r=20.D0 d=1.64D0
#    2.9860176670482680D+01  8.9136121471548291D-01 -7.0646581898801930D-01
#   -1.2057659961006690D-04  3.1550260069521060D-03 -6.2238202765842714D-05
#  0.D0 0.D0 0.D0

# %%
print(f"Epoch : {epochs.jd}")

for name, info in SMALL.items():
    obj = Horizons(id=info['id'], location='@sun', epochs=epochs.jd)
    el = obj.elements()

    a, e, i, w, node, M = el['a'][0], el['e'][0], el['incl'][0], el['w'][0], el['Omega'][0], el['M'][0]

    print(f" {name:<10} ep={epochs.jd:.1f}d0")
    print(f"  {a:.16f}d0 {e:.16f}d0 {i:.16f}d0 {w:.16f}d0 {node:.16f}d0 {M:.16f}d0 0.d0 0.d0 0.d0")
# Out:
# Epoch : 2461159.5
#  HEKTOR     ep=2461159.5d0
#   5.2768254774850840d0 0.0243380253800434d0 18.1472992810445213d0 181.1494672717840047d0 342.8020743195012869d0 21.7136169915900012d0 0.d0 0.d0 0.d0
