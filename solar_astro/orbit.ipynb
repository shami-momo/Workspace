# %%
from astroquery.jplhorizons import Horizons
from astropy.time import Time

# %%
DAYS_PER_JULIAN_YEAR = 365.25

BIG = {
    'MERCURY':   {'id': '1',   'm': '1.6601367952719304D-07', 'r': '20.D0', 'd': '5.43D0'},
    'VENUS':     {'id': '2',   'm': '2.4478383396645443D-06', 'r': '20.D0', 'd': '5.24D0'},
    'EARTHMOON': {'id': '3',   'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    'MARS':      {'id': '4',   'm': '3.2271514450538653D-07', 'r': '20.D0', 'd': '3.93D0'},
    'JUPITER':   {'id': '5',   'm': '9.5479193842432660D-04', 'r': '20.D0', 'd': '1.33D0'},
    'SATURN':    {'id': '6',   'm': '2.8588598066613081D-04', 'r': '20.D0', 'd': '0.69D0'},
    'URANUS':    {'id': '7',   'm': '4.3662440433515630D-05', 'r': '20.D0', 'd': '1.27D0'},
    'NEPTUNE':   {'id': '8',   'm': '5.1513890204661145D-05', 'r': '20.D0', 'd': '1.64D0'},
    'EARTH':    {'id': '399', 'm': '3.0034895963248533D-06', 'r': '20.D0', 'd': '5.51D0'},
    'MOON':     {'id': '301', 'm': '3.694873455835E-08',     'r': '20.D0', 'd': '3.34D0'}
}

SMALL = {
    #'HEKTOR':   {'id': 'Hektor'},
    'APOPHIS':   {'id': 'Apophis'},
    '2002AA29':  {'id': '2002 AA29'}
}

# %%
# Epoch Calculation
epochs_start = Time('2537-01-01 00:00:00', format='iso', scale='utc')
epochs_end = Time('2576-07-01 00:00:00', format='iso', scale='utc')
print(f"Epoch : {epochs_start.jd} to {epochs_end.jd}")
# Out:
# Epoch : 2647680.5 to 2662106.5

# %%
print(f"Epoch : {epochs_start.jd}\n")

for name, info in BIG.items():

    obj = Horizons(id=info['id'], location='@sun', epochs=epochs_start.jd)
    vec = obj.vectors()

    x, y, z = vec['x'][0], vec['y'][0], vec['z'][0]
    vx, vy, vz = vec['vx'][0], vec['vy'][0], vec['vz'][0]

    def to_d_format(val):

        return f"{val: .16E}".replace('E', 'D')

    print(f" {name:<10} m={info['m']} r={info['r']} d={info['d']}")
    print(f"  {to_d_format(x)} {to_d_format(y)} {to_d_format(z)}")
    print(f"  {to_d_format(vx)} {to_d_format(vy)} {to_d_format(vz)}")
    print(" 0.D0 0.D0 0.D0")
# Out:
# Epoch : 2461041.5
#
#  MERCURY    m=1.6601367952719304D-07 r=20.D0 d=5.43D0
#   -2.1520130437766771D-01 -4.0920761570027209D-01 -1.3703269591923660D-02
#    1.9231852282811691D-02 -1.1737626277575660D-02 -2.7231559251677290D-03
#  0.D0 0.D0 0.D0
#  VENUS      m=2.4478383396645443D-06 r=20.D0 d=5.24D0
#    8.8877249616356555D-02 -7.2176238231708068D-01 -1.5044056575061930D-02
#    1.9938560187967962D-02  2.4003658927385968D-03 -1.1174717964652810D-03
#  0.D0 0.D0 0.D0
#  EARTHMOON  m=3.0034895963248533D-06 r=20.D0 d=5.51D0
#   -1.7426975854830509D-01  9.6778567432419127D-01 -5.6866081362455097D-05
#   -1.7211595193051099D-02 -3.1136535800272498D-03  2.7637277605948441D-07
#  0.D0 0.D0 0.D0
#  MARS       m=3.2271514450538653D-07 r=20.D0 d=3.93D0
#    3.4057967686208740D-01 -1.3870020159459231D+00 -3.7417226787681959D-02
#    1.4119411970129980D-02  4.5402031901346394D-03 -2.5108536765334452D-04
#  0.D0 0.D0 0.D0
#  JUPITER    m=9.5479193842432660D-04 r=20.D0 d=1.33D0
#   -1.6940030301858460D+00  4.9288827146362326D+00  1.7426239903324200D-02
#   -7.2306158993227596D-03 -2.1015398603784802D-03  1.7050092685771419D-04
#  0.D0 0.D0 0.D0
#  SATURN     m=2.8588598066613081D-04 r=20.D0 d=0.69D0
#    9.5073433652218711D+00  2.5773845780215221D-01 -3.8293552850775309D-01
#   -4.6308454961069002D-04  5.5646721518635249D-03 -7.8489259087878715D-05
#  0.D0 0.D0 0.D0
#  URANUS     m=4.3662440433515630D-05 r=20.D0 d=1.27D0
#    9.8803179751942753D+00  1.6800015409817949D+01 -6.5719799137314322D-02
#   -3.4264010522871641D-03  1.8103776143017980D-03  5.1154063334464780D-05
#  0.D0 0.D0 0.D0
#  NEPTUNE    m=5.1513890204661145D-05 r=20.D0 d=1.64D0
#    2.9872120040888980D+01  5.1893946324112594D-01 -6.9906717520362904D-01
#   -8.1797229085048311D-05  3.1571073514127159D-03 -6.3163328574089735D-05
#  0.D0 0.D0 0.D0
#  EARTH      m=3.0034895963248533D-06 r=20.D0 d=5.51D0
#   -1.7428148092058329D-01  9.6775892025460308D-01 -5.9445110175262432D-05
#   -1.7204547368681291D-02 -3.1166070225443019D-03  2.3717827822404430D-07
#  0.D0 0.D0 0.D0
#  MOON       m=3.694873455835E-08 r=20.D0 d=3.34D0
#   -1.7331672302117879D-01  9.6996079538393698D-01  1.5281042658218431D-04
#   -1.7784587319041891D-02 -2.8735370251813659D-03  3.4629077212468181D-06
#  0.D0 0.D0 0.D0

# %%
print(f"Epoch : {epochs_start.jd}")

for name, info in SMALL.items():
    obj = Horizons(id=info['id'], location='@sun', epochs=epochs_start.jd)
    el = obj.elements()

    a, e, i, w, node, M = el['a'][0], el['e'][0], el['incl'][0], el['w'][0], el['Omega'][0], el['M'][0]

    print(f" {name:<10} ep={epochs_start.jd:.1f}d0")
    print(f"  {a:.16f}d0 {e:.16f}d0 {i:.16f}d0 {w:.16f}d0 {node:.16f}d0 {M:.16f}d0 0.d0 0.d0 0.d0")
# Out:
# Epoch : 2461041.5
#  APOPHIS    ep=2461041.5d0
#   0.9223741196612864d0 0.1911599236523363d0 3.3409583457925538d0 126.6733155317589024d0 203.8990676461006899d0 358.4220382278124930d0 0.d0 0.d0 0.d0
#  2002AA29   ep=2461041.5d0
#   0.9926075609998342d0 0.0130113040254415d0 10.7482401458019208d0 101.8314112466731984d0 106.3483835307658012d0 339.3753188744169051d0 0.d0 0.d0 0.d0
